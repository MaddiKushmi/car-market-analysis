# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/1776311302-P3-Car Market Trends Analysis with Car Dekho Data (2).csv")

# %%
print("Number of rows:", df.shape[0])
# Out:
# Number of rows: 301

# %%
print("Number of columns:", df.shape[1])
# Out:
# Number of columns: 9

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.columns.tolist()
# Out:
# ['Car_Name',
#  'Year',
#  'Selling_Price',
#  'Present_Price',
#  'Kms_Driven',
#  'Fuel_Type',
#  'Seller_Type',
#  'Transmission',
#  'Owner']

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# No missing values were found in the dataset.

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 2

# %%
df = df.drop_duplicates()

print("Duplicate rows removed.")
print("New dataset shape:", df.shape)
# Out:
# Duplicate rows removed.
# New dataset shape: (299, 9)

# %%
display(df.describe())
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   299.000000     299.000000     299.000000     299.000000  299.000000
# mean   2013.615385       4.589632       7.541037   36916.752508    0.043478
# std       2.896868       4.984240       8.567887   39015.170352    0.248720
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.850000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.510000       6.100000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.840000   48883.500000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
print("Number of cars by fuel type:")
print(df["Fuel_Type"].value_counts())
# Out:
# Number of cars by fuel type:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x="Fuel_Type")

plt.title("Number of Cars by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Number of Cars")

plt.show()

# %%
fuel_price = df.groupby("Fuel_Type")["Selling_Price"].mean()

print("Average Selling Price by Fuel Type:")
print(fuel_price)
# Out:
# Average Selling Price by Fuel Type:
# Fuel_Type
# CNG        3.100000
# Diesel    10.102759
# Petrol     3.264184
# Name: Selling_Price, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Fuel_Type",
    y="Selling_Price"
)

plt.title("Average Selling Price by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Average Selling Price")

plt.show()

# %%
print("Number of cars by transmission:")
print(df["Transmission"].value_counts())
# Out:
# Number of cars by transmission:
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Transmission",
    y="Selling_Price"
)

plt.title("Average Selling Price by Transmission")
plt.xlabel("Transmission")
plt.ylabel("Average Selling Price")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x="Present_Price",
    y="Selling_Price"
)

plt.title("Present Price vs Selling Price")
plt.xlabel("Present Price")
plt.ylabel("Selling Price")

plt.show()

# %%
correlation = df["Present_Price"].corr(df["Selling_Price"])

print("Correlation between Present Price and Selling Price:")
print(round(correlation, 2))
# Out:
# Correlation between Present Price and Selling Price:
# 0.88

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x="Kms_Driven",
    y="Selling_Price"
)

plt.title("Kilometres Driven vs Selling Price")
plt.xlabel("Kilometres Driven")
plt.ylabel("Selling Price")

plt.show()

# %%
year_price = df.groupby("Year")["Selling_Price"].mean()

print("Average Selling Price by Year:")
print(year_price)
# Out:
# Average Selling Price by Year:
# Year
# 2003    1.300000
# 2004    1.500000
# 2005    2.487500
# 2006    1.437500
# 2007    0.160000
# 2008    1.002857
# 2009    2.816667
# 2010    5.262667
# 2011    2.375263
# 2012    3.841304
# 2013    3.540909
# 2014    4.762105
# 2015    5.642500
# 2016    5.161429
# 2017    6.209143
# 2018    9.250000
# Name: Selling_Price, dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.lineplot(
    x=year_price.index,
    y=year_price.values,
    marker="o"
)

plt.title("Average Selling Price by Manufacturing Year")
plt.xlabel("Manufacturing Year")
plt.ylabel("Average Selling Price")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,6))

numeric_data = df.select_dtypes(include=np.number)

sns.heatmap(
    numeric_data.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
print("KEY FINDINGS")
print("-" * 40)

print("1. The dataset contains information about used cars and their pricing.")
print("2. No missing values were found in the dataset.")
print("3. Duplicate records were identified and removed.")
print("4. Present Price has a strong positive relationship with Selling Price.")
print("5. Selling prices vary across different fuel types.")
print("6. Selling prices differ between automatic and manual transmission cars.")
print("7. Manufacturing year and kilometres driven can be studied as factors affecting used-car prices.")
# Out:
# KEY FINDINGS
# ----------------------------------------
# 1. The dataset contains information about used cars and their pricing.
# 2. No missing values were found in the dataset.
# 3. Duplicate records were identified and removed.
# 4. Present Price has a strong positive relationship with Selling Price.
# 5. Selling prices vary across different fuel types.
# 6. Selling prices differ between automatic and manual transmission cars.
# 7. Manufacturing year and kilometres driven can be studied as factors affecting used-car prices.
